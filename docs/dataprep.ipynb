# %% [markdown]
# # Data Preparation
#
# ER-Evaluation expects clusterings and disambiguations to be represented as **membership vectors**, as checked by the {py:func}`er_evaluation.ismembership` function.

# %%
2+2
# Out:
# 4
