# %%
import pandas as pd

# %% [markdown]
# ### Load data

# %%
inventor = pd.read_csv("https://s3.amazonaws.com/data.patentsview.org/download/g_inventor_not_disambiguated.tsv.zip", sep="\t", dtype=str, compression="zip")
attorney = pd.read_csv("https://s3.amazonaws.com/data.patentsview.org/download/g_attorney_not_disambiguated.tsv.zip", sep="\t", dtype=str, compression="zip")
location = pd.read_csv("https://s3.amazonaws.com/data.patentsview.org/download/g_location_not_disambiguated.tsv.zip", sep="\t", dtype=str, compression="zip")
patent = pd.read_csv("https://s3.amazonaws.com/data.patentsview.org/download/g_patent.tsv.zip", sep="\t", dtype=str, compression="zip")
application = pd.read_csv("https://s3.amazonaws.com/data.patentsview.org/download/g_application.tsv.zip", sep="\t", dtype=str, compression="zip")
assignee = pd.read_csv("https://s3.amazonaws.com/data.patentsview.org/download/g_assignee_not_disambiguated.tsv.zip", sep="\t", dtype=str, compression="zip")
cpc_current = pd.read_csv("https://s3.amazonaws.com/data.patentsview.org/download/g_cpc_current.tsv.zip", sep="\t", dtype=str, compression="zip")
persistent_inventor = pd.read_csv("https://s3.amazonaws.com/data.patentsview.org/download/g_persistent_inventor.tsv.zip", sep="\t", dtype=str, compression="zip")

# %%
from pv_evaluation.benchmark import load_binette_2022_inventors_benchmark

binette_benchmark = load_binette_2022_inventors_benchmark()

# %% [markdown]
# Add "mention_id"

# %%
persistent_inventor['mention_id'] = "US" + persistent_inventor["patent_id"] + "-" + persistent_inventor["sequence"]
inventor['mention_id'] = "US" + inventor["patent_id"] + "-" + inventor["inventor_sequence"]

# %% [markdown]
# Add block IDs

# %%
inventor["block"] = inventor["inventor_id"].str.replace("-[1-9]+", "", regex=True)

# %% [markdown]
# ### Subset inventor mentions to blocks which intersect benchmark

# %%
pv_disamb = persistent_inventor.set_index("mention_id")["disamb_inventor_id_20211230"]

intersecting_blocks = inventor.set_index("mention_id").loc[binette_benchmark.index.values, "block"]

# Subset to sampled blocks
inventor_subset = inventor[inventor["block"].isin(intersecting_blocks)]

# Subset to inventor mentions which appear in the 2022/12/31 disambiguation
inventor_subset = inventor_subset[inventor_subset["mention_id"].isin(pv_disamb.index)]

# %% [markdown]
# ### Add features

# %% [markdown]
# #### Ground truth

# %%
# Add ground truth clusters as "unique_id"
inventor_subset = inventor_subset.merge(binette_benchmark.reset_index(), on="mention_id", how="left")
inventor_subset
# Out:
#        patent_id inventor_sequence            inventor_id  \
# 0        5828387                 4  fl:ha_ln:takahashi-18
# 1        8031420                 4       fl:yu_ln:lee-197
# 2       10692631                 0       fl:se_ln:lee-473
# 3        7976910                 2        fl:se_ln:lee-37
# 4        5073693                 0    fl:hi_ln:kikuchi-44
# ...          ...               ...                    ...
# 133536   4793455                 2       fl:ki_ln:kato-42
# 133537   4673655                 2     fl:hi_ln:yamada-29
# 133538   9740948                 0    fl:ke_ln:yoshida-46
# 133539  10178129                 2        fl:ju_ln:li-112
# 133540   6762742                 3      fl:hy_ln:choi-357
#
#        raw_inventor_name_first raw_inventor_name_last deceased_flag  \
# 0                     Haruhiko              Takahashi         FALSE
# 1                    Yuan Xing                    Lee         FALSE
# 2                      Seok Ju                    Lee         FALSE
# 3                    Seong-Nam                    Lee         FALSE
# 4                    Hiroyoshi                Kikuchi         FALSE
# ...                        ...                    ...           ...
# 133536                 Kichiro                   Kato         FALSE
# 133537               Hiromichi                 Yamada         FALSE
# 133538                   Kenji                Yoshida         FALSE
# 133539                     Jun                     Li         FALSE
# 133540              Hyeong-Bae                   Choi         FALSE
#
#                    rawlocation_id    mention_id               block unique_id
# 0       up2wnx1jqb31andxw48p7h0w5   US5828387-4  fl:ha_ln:takahashi       NaN
# 1       1lost5de91g151xmycuyw2o6k   US8031420-4        fl:yu_ln:lee       NaN
# 2       qguhzxr55o7oegny2obuiuwac  US10692631-0        fl:se_ln:lee       NaN
# 3       ccsmmyiqezysgon3iczipzgg7   US7976910-2        fl:se_ln:lee       NaN
# 4       2kl0hp6x059e2k3ta5yzvzlu2   US5073693-0    fl:hi_ln:kikuchi       NaN
# ...                           ...           ...                 ...       ...
# 133536  auiqhejy00iud5vbq6tzb38p7   US4793455-2       fl:ki_ln:kato       NaN
# 133537  fzfi1c54nh8bzsf9cnthxxb80   US4673655-2     fl:hi_ln:yamada       NaN
# 133538  zy8l73yf68ua6rjprzjkiicg6   US9740948-0    fl:ke_ln:yoshida       NaN
# 133539  j95fb46xte3bfd4183j6np00o  US10178129-2         fl:ju_ln:li       NaN
# 133540  wgkbe2tb85vnrra0oiqbymlam   US6762742-3       fl:hy_ln:choi       NaN
#
# [133541 rows x 10 columns]

# %% [markdown]
# #### Location

# %%
inventor_subset = inventor_subset.merge(location, on="rawlocation_id", how="left")
inventor_subset
# Out:
#        patent_id inventor_sequence            inventor_id  \
# 0        5828387                 4  fl:ha_ln:takahashi-18
# 1        8031420                 4       fl:yu_ln:lee-197
# 2       10692631                 0       fl:se_ln:lee-473
# 3        7976910                 2        fl:se_ln:lee-37
# 4        5073693                 0    fl:hi_ln:kikuchi-44
# ...          ...               ...                    ...
# 133536   4793455                 2       fl:ki_ln:kato-42
# 133537   4673655                 2     fl:hi_ln:yamada-29
# 133538   9740948                 0    fl:ke_ln:yoshida-46
# 133539  10178129                 2        fl:ju_ln:li-112
# 133540   6762742                 3      fl:hy_ln:choi-357
#
#        raw_inventor_name_first raw_inventor_name_last deceased_flag  \
# 0                     Haruhiko              Takahashi         FALSE
# 1                    Yuan Xing                    Lee         FALSE
# 2                      Seok Ju                    Lee         FALSE
# 3                    Seong-Nam                    Lee         FALSE
# 4                    Hiroyoshi                Kikuchi         FALSE
# ...                        ...                    ...           ...
# 133536                 Kichiro                   Kato         FALSE
# 133537               Hiromichi                 Yamada         FALSE
# 133538                   Kenji                Yoshida         FALSE
# 133539                     Jun                     Li         FALSE
# 133540              Hyeong-Bae                   Choi         FALSE
#
#                    rawlocation_id    mention_id               block unique_id  \
# 0       up2wnx1jqb31andxw48p7h0w5   US5828387-4  fl:ha_ln:takahashi       NaN
# 1       1lost5de91g151xmycuyw2o6k   US8031420-4        fl:yu_ln:lee       NaN
# 2       qguhzxr55o7oegny2obuiuwac  US10692631-0        fl:se_ln:lee       NaN
# 3       ccsmmyiqezysgon3iczipzgg7   US7976910-2        fl:se_ln:lee       NaN
# 4       2kl0hp6x059e2k3ta5yzvzlu2   US5073693-0    fl:hi_ln:kikuchi       NaN
# ...                           ...           ...                 ...       ...
# 133536  auiqhejy00iud5vbq6tzb38p7   US4793455-2       fl:ki_ln:kato       NaN
# 133537  fzfi1c54nh8bzsf9cnthxxb80   US4673655-2     fl:hi_ln:yamada       NaN
# 133538  zy8l73yf68ua6rjprzjkiicg6   US9740948-0    fl:ke_ln:yoshida       NaN
# 133539  j95fb46xte3bfd4183j6np00o  US10178129-2         fl:ju_ln:li       NaN
# 133540  wgkbe2tb85vnrra0oiqbymlam   US6762742-3       fl:hy_ln:choi       NaN
#
#                                  location_id   raw_city raw_state raw_country
# 0       1d2251c8-16c8-11ed-9b5f-1234bde3cd05   Yokohama       NaN         JPX
# 1       13f05eea-16c8-11ed-9b5f-1234bde3cd05   San Jose        CA          US
# 2       3eea8bf8-16c8-11ed-9b5f-1234bde3cd05   Suwon-si       NaN          KR
# 3       1aeb3c64-16c8-11ed-9b5f-1234bde3cd05      Seoul       NaN          KR
# 4       210d529a-16c8-11ed-9b5f-1234bde3cd05  Narashino       NaN          JP
# ...                                      ...        ...       ...         ...
# 133536  11f50cd8-16c8-11ed-9b5f-1234bde3cd05     Susono       NaN          JP
# 133537  9df01a7b-16c8-11ed-9b5f-1234bde3cd05     Akashi       NaN          JP
# 133538  42f90495-16c8-11ed-9b5f-1234bde3cd05      Tokyo       NaN          JP
# 133539  93778f03-16c8-11ed-9b5f-1234bde3cd05   Shenzhen       NaN          CN
# 133540  1aeb3c64-16c8-11ed-9b5f-1234bde3cd05      Seoul       NaN          KR
#
# [133541 rows x 14 columns]

# %% [markdown]
# #### Attorney

# %%
attorney_subset = attorney[attorney["patent_id"].isin(inventor_subset["patent_id"])]
attorney_by_patent = attorney_subset.groupby("patent_id").agg({
    "raw_attorney_name_first": list,
    "raw_attorney_name_last": list,
    "raw_attorney_organization": list,
    "attorney_country": list,
    "attorney_sequence": list
})
inventor_subset = inventor_subset.merge(attorney_by_patent, on="patent_id", how="left")
inventor_subset
# Out:
#        patent_id inventor_sequence            inventor_id  \
# 0        5828387                 4  fl:ha_ln:takahashi-18
# 1        8031420                 4       fl:yu_ln:lee-197
# 2       10692631                 0       fl:se_ln:lee-473
# 3        7976910                 2        fl:se_ln:lee-37
# 4        5073693                 0    fl:hi_ln:kikuchi-44
# ...          ...               ...                    ...
# 133536   4793455                 2       fl:ki_ln:kato-42
# 133537   4673655                 2     fl:hi_ln:yamada-29
# 133538   9740948                 0    fl:ke_ln:yoshida-46
# 133539  10178129                 2        fl:ju_ln:li-112
# 133540   6762742                 3      fl:hy_ln:choi-357
#
#        raw_inventor_name_first raw_inventor_name_last deceased_flag  \
# 0                     Haruhiko              Takahashi         FALSE
# 1                    Yuan Xing                    Lee         FALSE
# 2                      Seok Ju                    Lee         FALSE
# 3                    Seong-Nam                    Lee         FALSE
# 4                    Hiroyoshi                Kikuchi         FALSE
# ...                        ...                    ...           ...
# 133536                 Kichiro                   Kato         FALSE
# 133537               Hiromichi                 Yamada         FALSE
# 133538                   Kenji                Yoshida         FALSE
# 133539                     Jun                     Li         FALSE
# 133540              Hyeong-Bae                   Choi         FALSE
#
#                    rawlocation_id    mention_id               block unique_id  \
# 0       up2wnx1jqb31andxw48p7h0w5   US5828387-4  fl:ha_ln:takahashi       NaN
# 1       1lost5de91g151xmycuyw2o6k   US8031420-4        fl:yu_ln:lee       NaN
# 2       qguhzxr55o7oegny2obuiuwac  US10692631-0        fl:se_ln:lee       NaN
# 3       ccsmmyiqezysgon3iczipzgg7   US7976910-2        fl:se_ln:lee       NaN
# 4       2kl0hp6x059e2k3ta5yzvzlu2   US5073693-0    fl:hi_ln:kikuchi       NaN
# ...                           ...           ...                 ...       ...
# 133536  auiqhejy00iud5vbq6tzb38p7   US4793455-2       fl:ki_ln:kato       NaN
# 133537  fzfi1c54nh8bzsf9cnthxxb80   US4673655-2     fl:hi_ln:yamada       NaN
# 133538  zy8l73yf68ua6rjprzjkiicg6   US9740948-0    fl:ke_ln:yoshida       NaN
# 133539  j95fb46xte3bfd4183j6np00o  US10178129-2         fl:ju_ln:li       NaN
# 133540  wgkbe2tb85vnrra0oiqbymlam   US6762742-3       fl:hy_ln:choi       NaN
#
#                                  location_id   raw_city raw_state raw_country  \
# 0       1d2251c8-16c8-11ed-9b5f-1234bde3cd05   Yokohama       NaN         JPX
# 1       13f05eea-16c8-11ed-9b5f-1234bde3cd05   San Jose        CA          US
# 2       3eea8bf8-16c8-11ed-9b5f-1234bde3cd05   Suwon-si       NaN          KR
# 3       1aeb3c64-16c8-11ed-9b5f-1234bde3cd05      Seoul       NaN          KR
# 4       210d529a-16c8-11ed-9b5f-1234bde3cd05  Narashino       NaN          JP
# ...                                      ...        ...       ...         ...
# 133536  11f50cd8-16c8-11ed-9b5f-1234bde3cd05     Susono       NaN          JP
# 133537  9df01a7b-16c8-11ed-9b5f-1234bde3cd05     Akashi       NaN          JP
# 133538  42f90495-16c8-11ed-9b5f-1234bde3cd05      Tokyo       NaN          JP
# 133539  93778f03-16c8-11ed-9b5f-1234bde3cd05   Shenzhen       NaN          CN
# 133540  1aeb3c64-16c8-11ed-9b5f-1234bde3cd05      Seoul       NaN          KR
#
#        raw_attorney_name_first raw_attorney_name_last  \
# 0                        [nan]                  [nan]
# 1                 [nan, Steve]      [nan, Mendelsohn]
# 2                        [nan]                  [nan]
# 3                        [nan]                  [nan]
# 4                        [nan]                  [nan]
# ...                        ...                    ...
# 133536                   [nan]                  [nan]
# 133537                   [nan]                  [nan]
# 133538                   [nan]                  [nan]
# 133539                   [nan]                  [nan]
# 133540                   [nan]                  [nan]
#
#                             raw_attorney_organization attorney_country  \
# 0               [Fitzpatrick, Cella, Harper & Scinto]            [nan]
# 1       [Mendelsohn, Drucker & Associates, P.C., nan]       [nan, nan]
# 2                                     [K&L Gates LLP]            [nan]
# 3                                [Cantor Colburn LLP]            [nan]
# 4               [Sughrue, Mion, Zinn, Macpeak & Seas]            [nan]
# ...                                               ...              ...
# 133536                     [Cushman, Darby & Cushman]            [nan]
# 133537    [Oblon, Fisher, Spivak, McClelland & Maier]            [nan]
# 133538                             [Duane Morris LLP]            [nan]
# 133539                            [Conley Rose, P.C.]            [nan]
# 133540                             [McGuireWoods LLP]             [US]
#
#        attorney_sequence
# 0                    [0]
# 1                 [0, 1]
# 2                    [0]
# 3                    [0]
# 4                    [0]
# ...                  ...
# 133536               [0]
# 133537               [0]
# 133538               [0]
# 133539               [0]
# 133540               [0]
#
# [133541 rows x 19 columns]

# %% [markdown]
# #### Patent information

# %%
patent_subset = patent[patent["patent_id"].isin(inventor_subset["patent_id"])]
inventor_subset = inventor_subset.merge(patent_subset, on="patent_id", how="left")
inventor_subset
# Out:
#        patent_id inventor_sequence            inventor_id  \
# 0        5828387                 4  fl:ha_ln:takahashi-18
# 1        8031420                 4       fl:yu_ln:lee-197
# 2       10692631                 0       fl:se_ln:lee-473
# 3        7976910                 2        fl:se_ln:lee-37
# 4        5073693                 0    fl:hi_ln:kikuchi-44
# ...          ...               ...                    ...
# 133536   4793455                 2       fl:ki_ln:kato-42
# 133537   4673655                 2     fl:hi_ln:yamada-29
# 133538   9740948                 0    fl:ke_ln:yoshida-46
# 133539  10178129                 2        fl:ju_ln:li-112
# 133540   6762742                 3      fl:hy_ln:choi-357
#
#        raw_inventor_name_first raw_inventor_name_last deceased_flag  \
# 0                     Haruhiko              Takahashi         FALSE
# 1                    Yuan Xing                    Lee         FALSE
# 2                      Seok Ju                    Lee         FALSE
# 3                    Seong-Nam                    Lee         FALSE
# 4                    Hiroyoshi                Kikuchi         FALSE
# ...                        ...                    ...           ...
# 133536                 Kichiro                   Kato         FALSE
# 133537               Hiromichi                 Yamada         FALSE
# 133538                   Kenji                Yoshida         FALSE
# 133539                     Jun                     Li         FALSE
# 133540              Hyeong-Bae                   Choi         FALSE
#
#                    rawlocation_id    mention_id               block unique_id  \
# 0       up2wnx1jqb31andxw48p7h0w5   US5828387-4  fl:ha_ln:takahashi       NaN
# 1       1lost5de91g151xmycuyw2o6k   US8031420-4        fl:yu_ln:lee       NaN
# 2       qguhzxr55o7oegny2obuiuwac  US10692631-0        fl:se_ln:lee       NaN
# 3       ccsmmyiqezysgon3iczipzgg7   US7976910-2        fl:se_ln:lee       NaN
# 4       2kl0hp6x059e2k3ta5yzvzlu2   US5073693-0    fl:hi_ln:kikuchi       NaN
# ...                           ...           ...                 ...       ...
# 133536  auiqhejy00iud5vbq6tzb38p7   US4793455-2       fl:ki_ln:kato       NaN
# 133537  fzfi1c54nh8bzsf9cnthxxb80   US4673655-2     fl:hi_ln:yamada       NaN
# 133538  zy8l73yf68ua6rjprzjkiicg6   US9740948-0    fl:ke_ln:yoshida       NaN
# 133539  j95fb46xte3bfd4183j6np00o  US10178129-2         fl:ju_ln:li       NaN
# 133540  wgkbe2tb85vnrra0oiqbymlam   US6762742-3       fl:hy_ln:choi       NaN
#
#         ... attorney_country attorney_sequence patent_type patent_date  \
# 0       ...            [nan]               [0]     utility  1998-10-27
# 1       ...       [nan, nan]            [0, 1]     utility  2011-10-04
# 2       ...            [nan]               [0]     utility  2020-06-23
# 3       ...            [nan]               [0]     utility  2011-07-12
# 4       ...            [nan]               [0]     utility  1991-12-17
# ...     ...              ...               ...         ...         ...
# 133536  ...            [nan]               [0]     utility  1988-12-27
# 133537  ...            [nan]               [0]     utility  1987-06-16
# 133538  ...            [nan]               [0]     utility  2017-08-22
# 133539  ...            [nan]               [0]     utility  2019-01-08
# 133540  ...             [US]               [0]     utility  2004-07-13
#
#                                              patent_title  \
# 0       Recording apparatus with compensation for vari...
# 1       Frequency-based approach for detection and cla...
# 2       Cryogenic cooling apparatus and connecting str...
# 3       Liquid crystals and liquid crystal display app...
# 4                     Method for joining metallic members
# ...                                                   ...
# 133536                           Electromagnetic coupling
# 133537  Method of analyzing oxygen or nitrogen contain...
# 133538  Information input/output device, and medium, u...
# 133539                 Network security method and device
# 133540  Apparatus and method for automatic brightness ...
#
#                                           patent_abstract wipo_kind  \
# 0        A recording apparatus employs a control unit ...         A
# 1       In a hard-disc drive read channel, frequency-b...        B2
# 2       The present invention relates to a cryogenic c...        B2
# 3       A liquid crystal includes about 50 wt % to abo...        B2
# 4        A method for joining a porous metallic member...         A
# ...                                                   ...       ...
# 133536   An electromagnetic coupling selectively trans...         A
# 133537   A method of quantitatively analyzing oxygen o...         A
# 133538  To achieve an information output device in whi...        B2
# 133539  A network security method and a device relatin...        B2
# 133540  An LCD device having a backlight generates a b...        B2
#
#        num_claims withdrawn                 filename
# 0               8         0  pftaps19981027_wk43.zip
# 1              23         0            ipg111004.xml
# 2              20         0            ipg200623.xml
# 3              14         0            ipg110712.xml
# 4               2         0  pftaps19911217_wk51.zip
# ...           ...       ...                      ...
# 133536          8         0  pftaps19881227_wk52.zip
# 133537          4         0  pftaps19870616_wk24.zip
# 133538         11         0            ipg170822.xml
# 133539         14         0            ipg190108.xml
# 133540         26         0             pg040713.zip
#
# [133541 rows x 27 columns]

# %% [markdown]
# #### Application

# %%
application_subset = application[application["patent_id"].isin(inventor_subset["patent_id"])]
inventor_subset = inventor_subset.merge(application_subset, on="patent_id", how="left")
inventor_subset
# Out:
#        patent_id inventor_sequence            inventor_id  \
# 0        5828387                 4  fl:ha_ln:takahashi-18
# 1        8031420                 4       fl:yu_ln:lee-197
# 2       10692631                 0       fl:se_ln:lee-473
# 3        7976910                 2        fl:se_ln:lee-37
# 4        5073693                 0    fl:hi_ln:kikuchi-44
# ...          ...               ...                    ...
# 133536   4793455                 2       fl:ki_ln:kato-42
# 133537   4673655                 2     fl:hi_ln:yamada-29
# 133538   9740948                 0    fl:ke_ln:yoshida-46
# 133539  10178129                 2        fl:ju_ln:li-112
# 133540   6762742                 3      fl:hy_ln:choi-357
#
#        raw_inventor_name_first raw_inventor_name_last deceased_flag  \
# 0                     Haruhiko              Takahashi         FALSE
# 1                    Yuan Xing                    Lee         FALSE
# 2                      Seok Ju                    Lee         FALSE
# 3                    Seong-Nam                    Lee         FALSE
# 4                    Hiroyoshi                Kikuchi         FALSE
# ...                        ...                    ...           ...
# 133536                 Kichiro                   Kato         FALSE
# 133537               Hiromichi                 Yamada         FALSE
# 133538                   Kenji                Yoshida         FALSE
# 133539                     Jun                     Li         FALSE
# 133540              Hyeong-Bae                   Choi         FALSE
#
#                    rawlocation_id    mention_id               block unique_id  \
# 0       up2wnx1jqb31andxw48p7h0w5   US5828387-4  fl:ha_ln:takahashi       NaN
# 1       1lost5de91g151xmycuyw2o6k   US8031420-4        fl:yu_ln:lee       NaN
# 2       qguhzxr55o7oegny2obuiuwac  US10692631-0        fl:se_ln:lee       NaN
# 3       ccsmmyiqezysgon3iczipzgg7   US7976910-2        fl:se_ln:lee       NaN
# 4       2kl0hp6x059e2k3ta5yzvzlu2   US5073693-0    fl:hi_ln:kikuchi       NaN
# ...                           ...           ...                 ...       ...
# 133536  auiqhejy00iud5vbq6tzb38p7   US4793455-2       fl:ki_ln:kato       NaN
# 133537  fzfi1c54nh8bzsf9cnthxxb80   US4673655-2     fl:hi_ln:yamada       NaN
# 133538  zy8l73yf68ua6rjprzjkiicg6   US9740948-0    fl:ke_ln:yoshida       NaN
# 133539  j95fb46xte3bfd4183j6np00o  US10178129-2         fl:ju_ln:li       NaN
# 133540  wgkbe2tb85vnrra0oiqbymlam   US6762742-3       fl:hy_ln:choi       NaN
#
#         ...                                    patent_abstract wipo_kind  \
# 0       ...   A recording apparatus employs a control unit ...         A
# 1       ...  In a hard-disc drive read channel, frequency-b...        B2
# 2       ...  The present invention relates to a cryogenic c...        B2
# 3       ...  A liquid crystal includes about 50 wt % to abo...        B2
# 4       ...   A method for joining a porous metallic member...         A
# ...     ...                                                ...       ...
# 133536  ...   An electromagnetic coupling selectively trans...         A
# 133537  ...   A method of quantitatively analyzing oxygen o...         A
# 133538  ...  To achieve an information output device in whi...        B2
# 133539  ...  A network security method and a device relatin...        B2
# 133540  ...  An LCD device having a backlight generates a b...        B2
#
#        num_claims withdrawn                 filename  \
# 0               8         0  pftaps19981027_wk43.zip
# 1              23         0            ipg111004.xml
# 2              20         0            ipg200623.xml
# 3              14         0            ipg110712.xml
# 4               2         0  pftaps19911217_wk51.zip
# ...           ...       ...                      ...
# 133536          8         0  pftaps19881227_wk52.zip
# 133537          4         0  pftaps19870616_wk24.zip
# 133538         11         0            ipg170822.xml
# 133539         14         0            ipg190108.xml
# 133540         26         0             pg040713.zip
#
#                               application_id patent_application_type  \
# 0       8                                                         08
# 1                              2010/12707820                      12
# 2                              2014/15526035                      15
# 3                              2008/12346218                      12
# 4                                  07/417945                      07
# ...                                      ...                     ...
# 133536                             07/080007                      07
# 133537                             06/739271                      06
# 133538                         2016/15054599                      15
# 133539                         2016/15153195                      15
# 133540                             09/961438                      09
#
#        filing_date series_code rule_47_flag
# 0       1994-12-06          08          0.0
# 1       2010-02-18          12          0.0
# 2       2014-11-11          15          0.0
# 3       2008-12-30          12          0.0
# 4       1989-10-06          07          0.0
# ...            ...         ...          ...
# 133536  1987-07-31          07          0.0
# 133537  1985-05-30          06          0.0
# 133538  2016-02-26          15          0.0
# 133539  2016-05-12          15          0.0
# 133540  2001-09-25          09          0.0
#
# [133541 rows x 32 columns]

# %% [markdown]
# #### Assignees

# %%
assignee_subset = assignee[assignee["patent_id"].isin(inventor_subset["patent_id"])]

assignee_by_patent = assignee_subset.groupby("patent_id").agg({
    "assignee_sequence":list,
    "raw_assignee_individual_name_first":list,
    "raw_assignee_individual_name_last":list,
    "raw_assignee_organization": list,
    "assignee_type":list
})
inventor_subset = inventor_subset.merge(assignee_by_patent, on="patent_id", how="left")
inventor_subset
# Out:
#        patent_id inventor_sequence            inventor_id  \
# 0        5828387                 4  fl:ha_ln:takahashi-18
# 1        8031420                 4       fl:yu_ln:lee-197
# 2       10692631                 0       fl:se_ln:lee-473
# 3        7976910                 2        fl:se_ln:lee-37
# 4        5073693                 0    fl:hi_ln:kikuchi-44
# ...          ...               ...                    ...
# 133536   4793455                 2       fl:ki_ln:kato-42
# 133537   4673655                 2     fl:hi_ln:yamada-29
# 133538   9740948                 0    fl:ke_ln:yoshida-46
# 133539  10178129                 2        fl:ju_ln:li-112
# 133540   6762742                 3      fl:hy_ln:choi-357
#
#        raw_inventor_name_first raw_inventor_name_last deceased_flag  \
# 0                     Haruhiko              Takahashi         FALSE
# 1                    Yuan Xing                    Lee         FALSE
# 2                      Seok Ju                    Lee         FALSE
# 3                    Seong-Nam                    Lee         FALSE
# 4                    Hiroyoshi                Kikuchi         FALSE
# ...                        ...                    ...           ...
# 133536                 Kichiro                   Kato         FALSE
# 133537               Hiromichi                 Yamada         FALSE
# 133538                   Kenji                Yoshida         FALSE
# 133539                     Jun                     Li         FALSE
# 133540              Hyeong-Bae                   Choi         FALSE
#
#                    rawlocation_id    mention_id               block unique_id  \
# 0       up2wnx1jqb31andxw48p7h0w5   US5828387-4  fl:ha_ln:takahashi       NaN
# 1       1lost5de91g151xmycuyw2o6k   US8031420-4        fl:yu_ln:lee       NaN
# 2       qguhzxr55o7oegny2obuiuwac  US10692631-0        fl:se_ln:lee       NaN
# 3       ccsmmyiqezysgon3iczipzgg7   US7976910-2        fl:se_ln:lee       NaN
# 4       2kl0hp6x059e2k3ta5yzvzlu2   US5073693-0    fl:hi_ln:kikuchi       NaN
# ...                           ...           ...                 ...       ...
# 133536  auiqhejy00iud5vbq6tzb38p7   US4793455-2       fl:ki_ln:kato       NaN
# 133537  fzfi1c54nh8bzsf9cnthxxb80   US4673655-2     fl:hi_ln:yamada       NaN
# 133538  zy8l73yf68ua6rjprzjkiicg6   US9740948-0    fl:ke_ln:yoshida       NaN
# 133539  j95fb46xte3bfd4183j6np00o  US10178129-2         fl:ju_ln:li       NaN
# 133540  wgkbe2tb85vnrra0oiqbymlam   US6762742-3       fl:hy_ln:choi       NaN
#
#         ...                        application_id patent_application_type  \
# 0       ...  8                                                         08
# 1       ...                         2010/12707820                      12
# 2       ...                         2014/15526035                      15
# 3       ...                         2008/12346218                      12
# 4       ...                             07/417945                      07
# ...     ...                                   ...                     ...
# 133536  ...                             07/080007                      07
# 133537  ...                             06/739271                      06
# 133538  ...                         2016/15054599                      15
# 133539  ...                         2016/15153195                      15
# 133540  ...                             09/961438                      09
#
#        filing_date series_code rule_47_flag assignee_sequence  \
# 0       1994-12-06          08          0.0               [0]
# 1       2010-02-18          12          0.0               [0]
# 2       2014-11-11          15          0.0               [0]
# 3       2008-12-30          12          0.0               [0]
# 4       1989-10-06          07          0.0               [0]
# ...            ...         ...          ...               ...
# 133536  1987-07-31          07          0.0         [0, 2, 1]
# 133537  1985-05-30          06          0.0               [0]
# 133538  2016-02-26          15          0.0               NaN
# 133539  2016-05-12          15          0.0               [0]
# 133540  2001-09-25          09          0.0               [0]
#
#        raw_assignee_individual_name_first raw_assignee_individual_name_last  \
# 0                                   [nan]                             [nan]
# 1                                   [nan]                             [nan]
# 2                                   [nan]                             [nan]
# 3                                   [nan]                             [nan]
# 4                                   [nan]                             [nan]
# ...                                   ...                               ...
# 133536                    [nan, nan, nan]                   [nan, nan, nan]
# 133537                              [nan]                             [nan]
# 133538                                NaN                               NaN
# 133539                              [nan]                             [nan]
# 133540                              [nan]                             [nan]
#
#                                 raw_assignee_organization    assignee_type
# 0                                [Canon Kabushiki Kaisha]            [3.0]
# 1                                       [LSI Corporation]            [2.0]
# 2                                [LS CABLE & SYSTEM LTD.]            [3.0]
# 3                         [Samsung Electronics Co., Ltd.]            [3.0]
# 4                                         [NDC Co., Ltd.]            [3.0]
# ...                                                   ...              ...
# 133536  [Nippondenso Co., Ltd., Bridgestone Corporatio...  [3.0, 3.0, 3.0]
# 133537                  [Kabushiki Kaisha Kobe Seiko Sho]            [3.0]
# 133538                                                NaN              NaN
# 133539                    [HUAWEI TECHNOLOGIES CO., LTD.]            [3.0]
# 133540                    [Samsung Electronics Co., Ltd.]            [3.0]
#
# [133541 rows x 37 columns]

# %% [markdown]
# #### CPC

# %%
cpc_current_subset = cpc_current[cpc_current["patent_id"].isin(inventor_subset["patent_id"])]
cpc_by_patent = cpc_current_subset.groupby("patent_id").agg({
    "cpc_sequence":list,
    "cpc_section": list,
    "cpc_class": list,
    "cpc_subclass": list,
    "cpc_group": list,
    "cpc_type": list,
})
inventor_subset = inventor_subset.merge(cpc_by_patent, on="patent_id", how="left")
inventor_subset
# Out:
#        patent_id inventor_sequence            inventor_id  \
# 0        5828387                 4  fl:ha_ln:takahashi-18
# 1        8031420                 4       fl:yu_ln:lee-197
# 2       10692631                 0       fl:se_ln:lee-473
# 3        7976910                 2        fl:se_ln:lee-37
# 4        5073693                 0    fl:hi_ln:kikuchi-44
# ...          ...               ...                    ...
# 133536   4793455                 2       fl:ki_ln:kato-42
# 133537   4673655                 2     fl:hi_ln:yamada-29
# 133538   9740948                 0    fl:ke_ln:yoshida-46
# 133539  10178129                 2        fl:ju_ln:li-112
# 133540   6762742                 3      fl:hy_ln:choi-357
#
#        raw_inventor_name_first raw_inventor_name_last deceased_flag  \
# 0                     Haruhiko              Takahashi         FALSE
# 1                    Yuan Xing                    Lee         FALSE
# 2                      Seok Ju                    Lee         FALSE
# 3                    Seong-Nam                    Lee         FALSE
# 4                    Hiroyoshi                Kikuchi         FALSE
# ...                        ...                    ...           ...
# 133536                 Kichiro                   Kato         FALSE
# 133537               Hiromichi                 Yamada         FALSE
# 133538                   Kenji                Yoshida         FALSE
# 133539                     Jun                     Li         FALSE
# 133540              Hyeong-Bae                   Choi         FALSE
#
#                    rawlocation_id    mention_id               block unique_id  \
# 0       up2wnx1jqb31andxw48p7h0w5   US5828387-4  fl:ha_ln:takahashi       NaN
# 1       1lost5de91g151xmycuyw2o6k   US8031420-4        fl:yu_ln:lee       NaN
# 2       qguhzxr55o7oegny2obuiuwac  US10692631-0        fl:se_ln:lee       NaN
# 3       ccsmmyiqezysgon3iczipzgg7   US7976910-2        fl:se_ln:lee       NaN
# 4       2kl0hp6x059e2k3ta5yzvzlu2   US5073693-0    fl:hi_ln:kikuchi       NaN
# ...                           ...           ...                 ...       ...
# 133536  auiqhejy00iud5vbq6tzb38p7   US4793455-2       fl:ki_ln:kato       NaN
# 133537  fzfi1c54nh8bzsf9cnthxxb80   US4673655-2     fl:hi_ln:yamada       NaN
# 133538  zy8l73yf68ua6rjprzjkiicg6   US9740948-0    fl:ke_ln:yoshida       NaN
# 133539  j95fb46xte3bfd4183j6np00o  US10178129-2         fl:ju_ln:li       NaN
# 133540  wgkbe2tb85vnrra0oiqbymlam   US6762742-3       fl:hy_ln:choi       NaN
#
#         ... raw_assignee_individual_name_first  \
# 0       ...                              [nan]
# 1       ...                              [nan]
# 2       ...                              [nan]
# 3       ...                              [nan]
# 4       ...                              [nan]
# ...     ...                                ...
# 133536  ...                    [nan, nan, nan]
# 133537  ...                              [nan]
# 133538  ...                                NaN
# 133539  ...                              [nan]
# 133540  ...                              [nan]
#
#        raw_assignee_individual_name_last  \
# 0                                  [nan]
# 1                                  [nan]
# 2                                  [nan]
# 3                                  [nan]
# 4                                  [nan]
# ...                                  ...
# 133536                   [nan, nan, nan]
# 133537                             [nan]
# 133538                               NaN
# 133539                             [nan]
# 133540                             [nan]
#
#                                 raw_assignee_organization    assignee_type  \
# 0                                [Canon Kabushiki Kaisha]            [3.0]
# 1                                       [LSI Corporation]            [2.0]
# 2                                [LS CABLE & SYSTEM LTD.]            [3.0]
# 3                         [Samsung Electronics Co., Ltd.]            [3.0]
# 4                                         [NDC Co., Ltd.]            [3.0]
# ...                                                   ...              ...
# 133536  [Nippondenso Co., Ltd., Bridgestone Corporatio...  [3.0, 3.0, 3.0]
# 133537                  [Kabushiki Kaisha Kobe Seiko Sho]            [3.0]
# 133538                                                NaN              NaN
# 133539                    [HUAWEI TECHNOLOGIES CO., LTD.]            [3.0]
# 133540                    [Samsung Electronics Co., Ltd.]            [3.0]
#
#                                              cpc_sequence  \
# 0                      [6, 2, 0, 1, 5, 9, 8, 7, 4, 10, 3]
# 1                                               [2, 1, 0]
# 2                                      [5, 2, 1, 0, 3, 4]
# 3              [3, 2, 9, 4, 7, 8, 11, 1, 0, 6, 10, 12, 5]
# 4                                                  [0, 1]
# ...                                                   ...
# 133536                                    [2, 4, 1, 0, 3]
# 133537                                                [0]
# 133538  [12, 4, 17, 15, 5, 18, 9, 13, 0, 10, 11, 19, 1...
# 133539                                       [0, 1, 2, 3]
# 133540                 [8, 5, 7, 2, 4, 6, 1, 9, 0, 10, 3]
#
#                                               cpc_section  \
# 0                       [H, H, H, H, H, H, H, H, H, H, H]
# 1                                               [G, G, G]
# 2                                      [Y, F, H, F, F, H]
# 3                 [C, G, C, C, C, C, G, C, C, C, G, G, C]
# 4                                                  [B, B]
# ...                                                   ...
# 133536                                    [F, F, F, F, F]
# 133537                                                [G]
# 133538  [G, A, A, H, A, A, G, H, G, G, G, A, A, G, G, ...
# 133539                                       [H, H, H, H]
# 133540                  [G, G, G, G, G, G, G, G, G, G, G]
#
#                                                 cpc_class  \
# 0       [H04, H04, H04, H04, H04, H04, H04, H04, H04, ...
# 1                                         [G11, G11, G11]
# 2                          [Y02, F25, H01, F25, F25, H01]
# 3       [C09, G02, C09, C09, C09, C09, G02, C09, C09, ...
# 4                                              [B23, B23]
# ...                                                   ...
# 133536                          [F16, F16, F16, F16, F16]
# 133537                                              [G01]
# 133538  [G07, A63, A63, H04, A63, A63, G06, H04, G06, ...
# 133539                               [H04, H04, H04, H04]
# 133540  [G09, G09, G09, G09, G09, G09, G09, G09, G09, ...
#
#                                              cpc_subclass  \
# 0       [H04N, H04N, H04N, H04N, H04N, H04N, H04N, H04...
# 1                                      [G11B, G11B, G11B]
# 2                    [Y02E, F25B, H01B, F25B, F25D, H01F]
# 3       [C09K, G02F, C09K, C09K, C09K, C09K, G02F, C09...
# 4                                            [B23K, B23K]
# ...                                                   ...
# 133536                     [F16D, F16D, F16D, F16D, F16D]
# 133537                                             [G01N]
# 133538  [G07F, A63F, A63F, H04N, A63F, A63F, G06K, H04...
# 133539                           [H04L, H04L, H04L, H04L]
# 133540  [G09G, G09G, G09G, G09G, G09G, G09G, G09G, G09...
#
#                                                 cpc_group  \
# 0       [H04N2201/04724, H04N1/12, H04N1/506, H04N1/04...
# 1                    [G11B27/36, G11B19/041, G11B20/1816]
# 2       [Y02E40/60, F25B9/00, H01B12/16, F25B9/002, F2...
# 3       [C09K2019/0407, G02F1/137, C09K2323/03, C09K20...
# 4                                  [B23K11/20, B23K11/14]
# ...                                                   ...
# 133536  [F16D27/112, F16D2027/008, F16D3/68, F16D3/76,...
# 133537                                      [G01N33/2025]
# 133538  [G07F17/322, A63F13/213, A63F2001/008, H04N5/2...
# 133539  [H04L63/20, H04L63/0218, H04L63/0236, H04L63/104]
# 133540  [G09G2320/0653, G09G2320/0606, G09G2320/064, G...
#
#                                                  cpc_type
# 0       [additional, additional, inventional, inventio...
# 1                 [inventional, inventional, inventional]
# 2       [additional, inventional, inventional, inventi...
# 3       [additional, inventional, additional, addition...
# 4                              [inventional, inventional]
# ...                                                   ...
# 133536  [inventional, additional, inventional, inventi...
# 133537                                      [inventional]
# 133538  [inventional, inventional, additional, inventi...
# 133539  [inventional, inventional, inventional, additi...
# 133540  [additional, additional, additional, additiona...
#
# [133541 rows x 43 columns]

# %% [markdown]
# #### Co-inventors

# %%
coinventors_subset = inventor[inventor["patent_id"].isin(inventor_subset["patent_id"])]
coinventors_by_patent = coinventors_subset.groupby("patent_id").agg({
    "inventor_sequence":list,
    "raw_inventor_name_first": list,
    "raw_inventor_name_last": list,
})
coinventors_by_patent = coinventors_by_patent.rename(columns={
    "inventor_sequence": "coinventor_sequence",
    "raw_inventor_name_first": "coinventor_name_first",
    "raw_inventor_name_last": "coinventor_name_last"
    })
inventor_subset = inventor_subset.merge(coinventors_by_patent, on="patent_id", how="left")
inventor_subset
# Out:
#        patent_id inventor_sequence            inventor_id  \
# 0        5828387                 4  fl:ha_ln:takahashi-18
# 1        8031420                 4       fl:yu_ln:lee-197
# 2       10692631                 0       fl:se_ln:lee-473
# 3        7976910                 2        fl:se_ln:lee-37
# 4        5073693                 0    fl:hi_ln:kikuchi-44
# ...          ...               ...                    ...
# 133536   4793455                 2       fl:ki_ln:kato-42
# 133537   4673655                 2     fl:hi_ln:yamada-29
# 133538   9740948                 0    fl:ke_ln:yoshida-46
# 133539  10178129                 2        fl:ju_ln:li-112
# 133540   6762742                 3      fl:hy_ln:choi-357
#
#        raw_inventor_name_first raw_inventor_name_last deceased_flag  \
# 0                     Haruhiko              Takahashi         FALSE
# 1                    Yuan Xing                    Lee         FALSE
# 2                      Seok Ju                    Lee         FALSE
# 3                    Seong-Nam                    Lee         FALSE
# 4                    Hiroyoshi                Kikuchi         FALSE
# ...                        ...                    ...           ...
# 133536                 Kichiro                   Kato         FALSE
# 133537               Hiromichi                 Yamada         FALSE
# 133538                   Kenji                Yoshida         FALSE
# 133539                     Jun                     Li         FALSE
# 133540              Hyeong-Bae                   Choi         FALSE
#
#                    rawlocation_id    mention_id               block unique_id  \
# 0       up2wnx1jqb31andxw48p7h0w5   US5828387-4  fl:ha_ln:takahashi       NaN
# 1       1lost5de91g151xmycuyw2o6k   US8031420-4        fl:yu_ln:lee       NaN
# 2       qguhzxr55o7oegny2obuiuwac  US10692631-0        fl:se_ln:lee       NaN
# 3       ccsmmyiqezysgon3iczipzgg7   US7976910-2        fl:se_ln:lee       NaN
# 4       2kl0hp6x059e2k3ta5yzvzlu2   US5073693-0    fl:hi_ln:kikuchi       NaN
# ...                           ...           ...                 ...       ...
# 133536  auiqhejy00iud5vbq6tzb38p7   US4793455-2       fl:ki_ln:kato       NaN
# 133537  fzfi1c54nh8bzsf9cnthxxb80   US4673655-2     fl:hi_ln:yamada       NaN
# 133538  zy8l73yf68ua6rjprzjkiicg6   US9740948-0    fl:ke_ln:yoshida       NaN
# 133539  j95fb46xte3bfd4183j6np00o  US10178129-2         fl:ju_ln:li       NaN
# 133540  wgkbe2tb85vnrra0oiqbymlam   US6762742-3       fl:hy_ln:choi       NaN
#
#         ...    assignee_type  \
# 0       ...            [3.0]
# 1       ...            [2.0]
# 2       ...            [3.0]
# 3       ...            [3.0]
# 4       ...            [3.0]
# ...     ...              ...
# 133536  ...  [3.0, 3.0, 3.0]
# 133537  ...            [3.0]
# 133538  ...              NaN
# 133539  ...            [3.0]
# 133540  ...            [3.0]
#
#                                              cpc_sequence  \
# 0                      [6, 2, 0, 1, 5, 9, 8, 7, 4, 10, 3]
# 1                                               [2, 1, 0]
# 2                                      [5, 2, 1, 0, 3, 4]
# 3              [3, 2, 9, 4, 7, 8, 11, 1, 0, 6, 10, 12, 5]
# 4                                                  [0, 1]
# ...                                                   ...
# 133536                                    [2, 4, 1, 0, 3]
# 133537                                                [0]
# 133538  [12, 4, 17, 15, 5, 18, 9, 13, 0, 10, 11, 19, 1...
# 133539                                       [0, 1, 2, 3]
# 133540                 [8, 5, 7, 2, 4, 6, 1, 9, 0, 10, 3]
#
#                                               cpc_section  \
# 0                       [H, H, H, H, H, H, H, H, H, H, H]
# 1                                               [G, G, G]
# 2                                      [Y, F, H, F, F, H]
# 3                 [C, G, C, C, C, C, G, C, C, C, G, G, C]
# 4                                                  [B, B]
# ...                                                   ...
# 133536                                    [F, F, F, F, F]
# 133537                                                [G]
# 133538  [G, A, A, H, A, A, G, H, G, G, G, A, A, G, G, ...
# 133539                                       [H, H, H, H]
# 133540                  [G, G, G, G, G, G, G, G, G, G, G]
#
#                                                 cpc_class  \
# 0       [H04, H04, H04, H04, H04, H04, H04, H04, H04, ...
# 1                                         [G11, G11, G11]
# 2                          [Y02, F25, H01, F25, F25, H01]
# 3       [C09, G02, C09, C09, C09, C09, G02, C09, C09, ...
# 4                                              [B23, B23]
# ...                                                   ...
# 133536                          [F16, F16, F16, F16, F16]
# 133537                                              [G01]
# 133538  [G07, A63, A63, H04, A63, A63, G06, H04, G06, ...
# 133539                               [H04, H04, H04, H04]
# 133540  [G09, G09, G09, G09, G09, G09, G09, G09, G09, ...
#
#                                              cpc_subclass  \
# 0       [H04N, H04N, H04N, H04N, H04N, H04N, H04N, H04...
# 1                                      [G11B, G11B, G11B]
# 2                    [Y02E, F25B, H01B, F25B, F25D, H01F]
# 3       [C09K, G02F, C09K, C09K, C09K, C09K, G02F, C09...
# 4                                            [B23K, B23K]
# ...                                                   ...
# 133536                     [F16D, F16D, F16D, F16D, F16D]
# 133537                                             [G01N]
# 133538  [G07F, A63F, A63F, H04N, A63F, A63F, G06K, H04...
# 133539                           [H04L, H04L, H04L, H04L]
# 133540  [G09G, G09G, G09G, G09G, G09G, G09G, G09G, G09...
#
#                                                 cpc_group  \
# 0       [H04N2201/04724, H04N1/12, H04N1/506, H04N1/04...
# 1                    [G11B27/36, G11B19/041, G11B20/1816]
# 2       [Y02E40/60, F25B9/00, H01B12/16, F25B9/002, F2...
# 3       [C09K2019/0407, G02F1/137, C09K2323/03, C09K20...
# 4                                  [B23K11/20, B23K11/14]
# ...                                                   ...
# 133536  [F16D27/112, F16D2027/008, F16D3/68, F16D3/76,...
# 133537                                      [G01N33/2025]
# 133538  [G07F17/322, A63F13/213, A63F2001/008, H04N5/2...
# 133539  [H04L63/20, H04L63/0218, H04L63/0236, H04L63/104]
# 133540  [G09G2320/0653, G09G2320/0606, G09G2320/064, G...
#
#                                                  cpc_type  \
# 0       [additional, additional, inventional, inventio...
# 1                 [inventional, inventional, inventional]
# 2       [additional, inventional, inventional, inventi...
# 3       [additional, inventional, additional, addition...
# 4                              [inventional, inventional]
# ...                                                   ...
# 133536  [inventional, additional, inventional, inventi...
# 133537                                      [inventional]
# 133538  [inventional, inventional, additional, inventi...
# 133539  [inventional, inventional, inventional, additi...
# 133540  [additional, additional, additional, additiona...
#
#           coinventor_sequence  \
# 0       [4, 5, 2, 3, 0, 1, 6]
# 1             [4, 3, 1, 2, 0]
# 2             [0, 3, 1, 2, 4]
# 3                [2, 0, 1, 3]
# 4                   [0, 1, 2]
# ...                       ...
# 133536           [3, 0, 1, 2]
# 133537        [3, 4, 1, 0, 2]
# 133538                    [0]
# 133539              [0, 1, 2]
# 133540           [2, 0, 1, 3]
#
#                                     coinventor_name_first  \
# 0       [Haruhiko, Makoto, Hidejiro, Ken, Masafumi, To...
# 1            [Yuan Xing, Zongwang, Yang, Shaohua, George]
# 2       [Seok Ju, Heo Gyung, Han Joong, Chang Yeol, Ji...
# 3               [Seong-Nam, Seon-Ah, Jang-Hyun, Jeong-Uk]
# 4                           [Hiroyoshi, Hiroto, Syunsuke]
# ...                                                   ...
# 133536                  [Tomoyuki, Yasuo, Masao, Kichiro]
# 133537    [Hiromi, Masami, Kiyoshi, Masayoshi, Hiromichi]
# 133538                                            [Kenji]
# 133539                                 [Yibin, Bing, Jun]
# 133540       [Dong-Won, Seung-Hwan, Sang-Soo, Hyeong-Bae]
#
#                                      coinventor_name_last
# 0       [Takahashi, Takamiya, Kadowaki, Tsuchii, Watay...
# 1                            [Lee, Li, Han, Yang, Mathew]
# 2                              [Lee, Sung, Kim, Choi, Na]
# 3                                    [Lee, Cho, Kim, Heo]
# 4                               [Kikuchi, Kosuge, Suzuki]
# ...                                                   ...
# 133536                    [Kurata, Tabuchi, Nakano, Kato]
# 133537        [Umeda, Tomimoto, Matsuda, Okamura, Yamada]
# 133538                                          [Yoshida]
# 133539                                      [Xu, Sun, Li]
# 133540                            [Park, Moon, Kim, Choi]
#
# [133541 rows x 46 columns]

# %% [markdown]
# ## Export

# %% [markdown]
# #### Base data

# %%
data_columns = [
    "mention_id",
    "block",
    "patent_id",
    "inventor_sequence",
    "raw_inventor_name_first",
    "raw_inventor_name_last",
    "deceased_flag",
    "raw_city",
    "raw_state",
    "raw_country",
    "raw_attorney_name_first",
    "raw_attorney_name_last",
    "raw_attorney_organization",
    "attorney_country",
    "attorney_sequence",
    "patent_type",
    "patent_date",
    "patent_title",
    "patent_abstract",
    "wipo_kind",
    "num_claims",
    "withdrawn",
    "patent_application_type",
    "filing_date",
    "series_code",
    "rule_47_flag",
    "assignee_sequence",
    "raw_assignee_individual_name_first",
    "raw_assignee_individual_name_last",
    "raw_assignee_organization",
    "assignee_type",
    "cpc_sequence",
    "cpc_section",
    "cpc_class",
    "cpc_subclass",
    "cpc_group",
    "cpc_type",
    "coinventor_sequence",
    "coinventor_name_first",
    "coinventor_name_last"
]

inventor_subset[data_columns].to_parquet("pv-data.parquet", engine="pyarrow", index=False)

# %% [markdown]
# #### Reference disambiguation

# %%
inventor_subset[["mention_id", "unique_id"]].to_parquet("pv-reference.parquet", engine="pyarrow", index=False)

# %% [markdown]
# #### Predictions

# %%
persistent_inventor_subset = persistent_inventor[persistent_inventor["mention_id"].isin(inventor_subset["mention_id"])]

# %%
persistent_inventor_subset.to_parquet("pv-predictions.parquet", engine="pyarrow", index=False)
